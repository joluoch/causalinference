# %%
import dowhy
from dowhy import CausalModel
import pandas as pd
import numpy as np


import logging

import dvc.api


import patsy as ps
import os, sys
from IPython.display import Image, display

# %%
data = pd.read_csv('../data/data_outlier.csv')
data.head(5)
# Out:
#    Unnamed: 0 diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           6         M        18.25         19.98           119.6     1040.0
# 1           7         M        13.71         20.83            90.2      577.9
# 2          10         M        16.02         23.24           102.7      797.8
# 3          11         M        15.78         17.89           103.6      781.0
# 4          13         M        15.85         23.95           103.7      782.7
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.09463           0.10900         0.11270              0.07400
# 1          0.11890           0.16450         0.09366              0.05985
# 2          0.08206           0.06669         0.03299              0.03323
# 3          0.09710           0.12920         0.09954              0.06606
# 4          0.08401           0.10020         0.09938              0.05364
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         22.88          27.66            153.2      1606.0
# 1  ...         17.06          28.14            110.6       897.0
# 2  ...         19.19          33.88            123.8      1150.0
# 3  ...         20.42          27.28            136.5      1299.0
# 4  ...         16.84          27.66            112.0       876.5
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1442             0.2576           0.3784               0.19320
# 1            0.1654             0.3682           0.2678               0.15560
# 2            0.1181             0.1551           0.1459               0.09975
# 3            0.1396             0.5609           0.3965               0.18100
# 4            0.1131             0.1924           0.2322               0.11190
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.3063                  0.08368
# 1          0.3196                  0.11510
# 2          0.2948                  0.08452
# 3          0.3792                  0.10480
# 4          0.2809                  0.06287
#
# [5 rows x 32 columns]
